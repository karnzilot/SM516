# %% [markdown]
# # <center>SM516 การโปรแกรมขั้นสูง

# %% [markdown]
# <img src="images/Supakarn.jpg" width=100 align="right">

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('O0cAx1jLbJk')

# %% [markdown]
# <div align="right">ศุภกาญจน์ วงศ์ชัยสุริยะ<br>วิศวกรรมการเงิน มกค.<br>๑๑ มกราคม ๒๕๖๓</div>

# %% [markdown]
# ## การวัดผล
#
# 1. กิจกรรมในห้องเรียน 40%
#     * สมุดจด 30%
#     * การโปรแกรม 10%
# * การบ้าน 20% $\rightarrow$ จัดเก็บลงบน **flashdrive** ส่งในวันสอบปลายภาค
# * สอบปลายภาค 60% (ได้คะแนนน้อยกว่า 15% ให้เรียนใหม่)

# %% [markdown]
# # การติดตั้งโปรแกรม
#
# 1. [Winpython](https://winpython.github.io/)
# ![](https://winpython.github.io/images/winpython_title.png)

# %% [markdown]
# ## เนื้อหา
#
# * Python
#     - Installation
#     - Jupyter Notebook
#         - Markdown
#             - Markdown
#             - Html
#             - LeTex
#     - Object Oriented Programimng (OOP)
#         - Object
#             - Single Object
#             - Containers
#             - OOP
#         - Expression
#             - Operators
#             - Logic
#         - Commands
#             - Conditions
#             - Repetition
#         - Module
#             - Packgagegs
#                 - math and cmath
#                 - numpy
#                 - matplotlib
#                 - pandas
#                 - sympy
#         - Program
#             - Jupyter Notebook/ Jupyter Lab
#             - vscode
#             - pyCharm
# * Repository and Code Version Control (GitHub)
# * Python for Finance
# * Python for Statistics
#
# * R Programming

# %% [markdown]
# ## เอกสารอ้างอิง
# * หนังสือหลักสำหรับ Python คือ  Mark Lutz [Learning Python, 5th_Edition](https://www.amazon.com/gp/product/1449355730)
#     - [Local_copy](MarkLutzLearningPython5th)
# * Johanson [Numerical Python, Robert Johannson](https://www.amazon.com/Numerical-Python-Scientific-Applications-Matplotlib/dp/1484242459/ref=pd_sbs_14_img_0/141-4553326-1367849?_encoding=UTF8&pd_rd_i=1484242459&pd_rd_r=63c6f8e5-01f2-4bd7-ba36-d2ed036c208b&pd_rd_w=0rdek&pd_rd_wg=YR6lp&pf_rd_p=5cfcfe89-300f-47d2-b1ad-a4e27203a02a&pf_rd_r=PYSVCG7HV5D2KEGTCC0X&psc=1&refRID=PYSVCG7HV5D2KEGTCC0X)
#     - [Local_copy](RobertJohanssonNumericalPython)

# %% [markdown]
# $\alpha$ zmnlkajs
#
# $$ ax^2 +bx +c =0 \tag{1}$$

# %% [markdown]
# $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a} \tag{2}$$

# %% [markdown]
# $$
# \left[
# \begin{array}{rrr}
# -1 & 0 & 1 \\
# -2 & -3 & 4 \\
# 3 & 12 & 256 \\
# \end{array}
# \right]
# \left[
# \begin{array}{c}
# x \\ y \\ z
# \end{array}
# \right]
# =
# \left[
# \begin{array}{1}
# 8 \\ 7 \\ 12
# \end{array}
# \right]
# \tag{3}
# $$

# %% [markdown]
# <u>เอกสาร</u>
